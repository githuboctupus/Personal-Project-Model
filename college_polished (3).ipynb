# %%
#this is solely to get the notebook to render on github
#before running this, github would give the message of invalid notebook
import json
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/MyDrive/college_polished.ipynb"
with open(path, "r", encoding="utf-8") as f:
    nb = json.load(f)

# Remove the problematic metadata
nb.get("metadata", {}).pop("widgets", None)

with open(path, "w", encoding="utf-8") as f:
    json.dump(nb, f, ensure_ascii=False, indent=1)

print("✅ Fixed:", path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Fixed: /content/drive/MyDrive/college_polished.ipynb

# %%
# !curl -L -o rescuenet.zip "https://www.dropbox.com/scl/fo/ntgeyhxe2mzd2wuh7he7x/AFIchlfjVO_7MzPcNc1ZOHE/RescueNet?rlkey=6vxiaqve9gp6vzvzh3t5mz0vv&subfolder_nav_tracking=1&st=cpmz72mg&dl=1"  #download the main rescuenet image archive directly into the notebook workspace
# !curl -L -o colormask.zip "https://www.dropbox.com/scl/fo/ntgeyhxe2mzd2wuh7he7x/AK7z2KSL2Df2igYzGrrHlYs/ColorMasks-RescueNet?dl=0&rlkey=6vxiaqve9gp6vzvzh3t5mz0vv&subfolder_nav_tracking=1&d=1"  #download the color-mask archive that pairs with the images
# !unzip rescuenet.zip -d rescuenettrain/  #unzip images into a dedicated folder so paths are predictable
# !unzip colormask.zip -d rescuenetmask/   #unzip masks into a parallel folder keeping train/test structure
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: rescuenettrain/train/train-label-img/11685_lab.png
#  extracting: rescuenettrain/train/train-label-img/11698_lab.png
#  extracting: rescuenettrain/train/train-label-img/11699_lab.png
#  extracting: rescuenettrain/train/train-label-img/11729_lab.png
#  extracting: rescuenettrain/train/train-label-img/11735_lab.png
#  extracting: rescuenettrain/train/train-label-img/11736_lab.png
#  extracting: rescuenettrain/train/train-label-img/11775_lab.png
#  extracting: rescuenettrain/train/train-label-img/11776_lab.png
#  extracting: rescuenettrain/train/train-label-img/11777_lab.png
#  extracting: rescuenettrain/train/train-label-img/11794_lab.png
#  extracting: rescuenettrain/train/train-label-img/11800_lab.png
#  extracting: rescuenettrain/train/train-label-img/11801_lab.png
#  extracting: rescuenettrain/train/train-label-img/11803_lab.png
#  extracting: rescuenettrain/train/train-label-img/11679_lab.png
#  extracting: rescuenettrain/train/train-label-img/11716_lab.png
#  extracting: rescuenettrain/train/train-label-img/11717_lab.png
#  extracting: rescuenettrain/train/train-label-img/11820_lab.png
#  extracting: rescuenettrain/train/train-label-img/11821_lab.png
#  extracting: rescuenettrain/train/train-label-img/11840_lab.png
#  extracting: rescuenettrain/train/train-label-img/11841_lab.png
#  extracting: rescuenettrain/train/train-label-img/11860_lab.png
#  extracting: rescuenettrain/train/train-label-img/11861_lab.png
#  extracting: rescuenettrain/train/train-label-img/10780_lab.png
#  extracting: rescuenettrain/train/train-label-img/11017_lab.png
#  extracting: rescuenettrain/train/train-label-img/11057_lab.png
#  extracting: rescuenettrain/train/train-label-img/11107_lab.png
#  extracting: rescuenettrain/train/train-label-img/11323_lab.png
#  extracting: rescuenettrain/train/train-label-img/11788_lab.png
#  extracting: rescuenettrain/train/train-label-img/11119_lab.png
#  extracting: rescuenettrain/train/train-label-img/11843_lab.png
#  extracting: rescuenettrain/train/train-label-img/11911_lab.png
#  extracting: rescuenettrain/train/train-label-img/11912_lab.png
#  extracting: rescuenettrain/train/train-label-img/11913_lab.png
#  extracting: rescuenettrain/train/train-label-img/11127_lab.png
#  extracting: rescuenettrain/train/train-label-img/11931_lab.png
#  extracting: rescuenettrain/train/train-label-img/11933_lab.png
#  extracting: rescuenettrain/train/train-label-img/11951_lab.png
#  extracting: rescuenettrain/train/train-label-img/11952_lab.png
#  extracting: rescuenettrain/train/train-label-img/11953_lab.png
#  extracting: rescuenettrain/train/train-label-img/11972_lab.png
#  extracting: rescuenettrain/train/train-label-img/11973_lab.png
#  extracting: rescuenettrain/train/train-label-img/11992_lab.png
#  extracting: rescuenettrain/train/train-label-img/10888_lab.png
#  extracting: rescuenettrain/train/train-label-img/11644_lab.png
#  extracting: rescuenettrain/train/train-label-img/12031_lab.png
#  extracting: rescuenettrain/train/train-label-img/12032_lab.png
#  extracting: rescuenettrain/train/train-label-img/12033_lab.png
#  extracting: rescuenettrain/train/train-label-img/12051_lab.png
#  extracting: rescuenettrain/train/train-label-img/12052_lab.png
#  extracting: rescuenettrain/train/train-label-img/12053_lab.png
#  extracting: rescuenettrain/train/train-label-img/12071_lab.png
#  extracting: rescuenettrain/train/train-label-img/12072_lab.png
#  extracting: rescuenettrain/train/train-label-img/12073_lab.png
#  extracting: rescuenettrain/train/train-label-img/11638_lab.png
#  extracting: rescuenettrain/train/train-label-img/11665_lab.png
#  extracting: rescuenettrain/train/train-label-img/11667_lab.png
#  extracting: rescuenettrain/train/train-label-img/12013_lab.png
#  extracting: rescuenettrain/train/train-label-img/12090_lab.png
#  extracting: rescuenettrain/train/train-label-img/12092_lab.png
#  extracting: rescuenettrain/train/train-label-img/12100_lab.png
#  extracting: rescuenettrain/train/train-label-img/12101_lab.png
#  extracting: rescuenettrain/train/train-label-img/12120_lab.png
#  extracting: rescuenettrain/train/train-label-img/12121_lab.png
#  extracting: rescuenettrain/train/train-label-img/12123_lab.png
#  extracting: rescuenettrain/train/train-label-img/12141_lab.png
#  extracting: rescuenettrain/train/train-label-img/12160_lab.png
#  extracting: rescuenettrain/train/train-label-img/12161_lab.png
#  extracting: rescuenettrain/train/train-label-img/12163_lab.png
#  extracting: rescuenettrain/train/train-label-img/12180_lab.png
#  extracting: rescuenettrain/train/train-label-img/12181_lab.png
#  extracting: rescuenettrain/train/train-label-img/12209_lab.png
#  extracting: rescuenettrain/train/train-label-img/12215_lab.png
#  extracting: rescuenettrain/train/train-label-img/12216_lab.png
#  extracting: rescuenettrain/train/train-label-img/12217_lab.png
#  extracting: rescuenettrain/train/train-label-img/12229_lab.png
#  extracting: rescuenettrain/train/train-label-img/12249_lab.png
#  extracting: rescuenettrain/train/train-label-img/12256_lab.png
#  extracting: rescuenettrain/train/train-label-img/12257_lab.png
#  extracting: rescuenettrain/train/train-label-img/12275_lab.png
#  extracting: rescuenettrain/train/train-label-img/12277_lab.png
#  extracting: rescuenettrain/train/train-label-img/12288_lab.png
#  extracting: rescuenettrain/train/train-label-img/12296_lab.png
#  extracting: rescuenettrain/train/train-label-img/12297_lab.png
#  extracting: rescuenettrain/train/train-label-img/12304_lab.png
#  extracting: rescuenettrain/train/train-label-img/12305_lab.png
#  extracting: rescuenettrain/train/train-label-img/12307_lab.png
#  extracting: rescuenettrain/train/train-label-img/12318_lab.png
#  extracting: rescuenettrain/train/train-label-img/12319_lab.png
#  extracting: rescuenettrain/train/train-label-img/12325_lab.png
#  extracting: rescuenettrain/train/train-label-img/12338_lab.png
#  extracting: rescuenettrain/train/train-label-img/12344_lab.png
#  extracting: rescuenettrain/train/train-label-img/12345_lab.png
#  extracting: rescuenettrain/train/train-label-img/12347_lab.png
#  extracting: rescuenettrain/train/train-label-img/12358_lab.png
#  extracting: rescuenettrain/train/train-label-img/12359_lab.png
#  extracting: rescuenettrain/train/train-label-img/12364_lab.png
#  extracting: rescuenettrain/train/train-label-img/12367_lab.png
#  extracting: rescuenettrain/train/train-label-img/12384_lab.png
#  extracting: rescuenettrain/train/train-label-img/12385_lab.png
#  extracting: rescuenettrain/train/train-label-img/11009_lab.png
#  extracting: rescuenettrain/train/train-label-img/11664_lab.png
#  extracting: rescuenettrain/train/train-label-img/12398_lab.png
#  extracting: rescuenettrain/train/train-label-img/12399_lab.png
#  extracting: rescuenettrain/train/train-label-img/12447_lab.png
#  extracting: rescuenettrain/train/train-label-img/12465_lab.png
#  extracting: rescuenettrain/train/train-label-img/12466_lab.png
#  extracting: rescuenettrain/train/train-label-img/12467_lab.png
#  extracting: rescuenettrain/train/train-label-img/12498_lab.png
#  extracting: rescuenettrain/train/train-label-img/12515_lab.png
#  extracting: rescuenettrain/train/train-label-img/12534_lab.png
#  extracting: rescuenettrain/train/train-label-img/12486_lab.png
#  extracting: rescuenettrain/train/train-label-img/12487_lab.png
#  extracting: rescuenettrain/train/train-label-img/12528_lab.png
#  extracting: rescuenettrain/train/train-label-img/12529_lab.png
#  extracting: rescuenettrain/train/train-label-img/12535_lab.png
#  extracting: rescuenettrain/train/train-label-img/12554_lab.png
#  extracting: rescuenettrain/train/train-label-img/12555_lab.png
#  extracting: rescuenettrain/train/train-label-img/12557_lab.png
#  extracting: rescuenettrain/train/train-label-img/12568_lab.png
#  extracting: rescuenettrain/train/train-label-img/12569_lab.png
#  extracting: rescuenettrain/train/train-label-img/12574_lab.png
#  extracting: rescuenettrain/train/train-label-img/12577_lab.png
#  extracting: rescuenettrain/train/train-label-img/12588_lab.png
#  extracting: rescuenettrain/train/train-label-img/12589_lab.png
#  extracting: rescuenettrain/train/train-label-img/12594_lab.png
#  extracting: rescuenettrain/train/train-label-img/12595_lab.png
#  extracting: rescuenettrain/train/train-label-img/12602_lab.png
#  extracting: rescuenettrain/train/train-label-img/12603_lab.png
#  extracting: rescuenettrain/train/train-label-img/12622_lab.png
#  extracting: rescuenettrain/train/train-label-img/12623_lab.png
#  extracting: rescuenettrain/train/train-label-img/12641_lab.png
#  extracting: rescuenettrain/train/train-label-img/12642_lab.png
#  extracting: rescuenettrain/train/train-label-img/12643_lab.png
#  extracting: rescuenettrain/train/train-label-img/12661_lab.png
#  extracting: rescuenettrain/train/train-label-img/12663_lab.png
#  extracting: rescuenettrain/train/train-label-img/12601_lab.png
#  extracting: rescuenettrain/train/train-label-img/12682_lab.png
#  extracting: rescuenettrain/train/train-label-img/12683_lab.png
#  extracting: rescuenettrain/train/train-label-img/12710_lab.png
#  extracting: rescuenettrain/train/train-label-img/12711_lab.png
#  extracting: rescuenettrain/train/train-label-img/12713_lab.png
#  extracting: rescuenettrain/train/train-label-img/12255_lab.png
#  extracting: rescuenettrain/train/train-label-img/12509_lab.png
#  extracting: rescuenettrain/train/train-label-img/12750_lab.png
#  extracting: rescuenettrain/train/train-label-img/12751_lab.png
#  extracting: rescuenettrain/train/train-label-img/12770_lab.png
#  extracting: rescuenettrain/train/train-label-img/12771_lab.png
#  extracting: rescuenettrain/train/train-label-img/12805_lab.png
#  extracting: rescuenettrain/train/train-label-img/12730_lab.png
#  extracting: rescuenettrain/train/train-label-img/12731_lab.png
#  extracting: rescuenettrain/train/train-label-img/12753_lab.png
#  extracting: rescuenettrain/train/train-label-img/12773_lab.png
#  extracting: rescuenettrain/train/train-label-img/12790_lab.png
#  extracting: rescuenettrain/train/train-label-img/12791_lab.png
#  extracting: rescuenettrain/train/train-label-img/12807_lab.png
#  extracting: rescuenettrain/train/train-label-img/12508_lab.png
#  extracting: rescuenettrain/train/train-label-img/12825_lab.png
#  extracting: rescuenettrain/train/train-label-img/12826_lab.png
#  extracting: rescuenettrain/train/train-label-img/12839_lab.png
#  extracting: rescuenettrain/train/train-label-img/12867_lab.png
#  extracting: rescuenettrain/train/train-label-img/12937_lab.png
#  extracting: rescuenettrain/train/train-label-img/12969_lab.png
#  extracting: rescuenettrain/train/train-label-img/12846_lab.png
#  extracting: rescuenettrain/train/train-label-img/12847_lab.png
#  extracting: rescuenettrain/train/train-label-img/12884_lab.png
#  extracting: rescuenettrain/train/train-label-img/12886_lab.png
#  extracting: rescuenettrain/train/train-label-img/12908_lab.png
#  extracting: rescuenettrain/train/train-label-img/12909_lab.png
#  extracting: rescuenettrain/train/train-label-img/12914_lab.png
#  extracting: rescuenettrain/train/train-label-img/12935_lab.png
#  extracting: rescuenettrain/train/train-label-img/12955_lab.png
#  extracting: rescuenettrain/train/train-label-img/12975_lab.png
#  extracting: rescuenettrain/train/train-label-img/12977_lab.png
#  extracting: rescuenettrain/train/train-label-img/12934_lab.png
#  extracting: rescuenettrain/train/train-label-img/13038_lab.png
#  extracting: rescuenettrain/train/train-label-img/13039_lab.png
#  extracting: rescuenettrain/train/train-label-img/13058_lab.png
#  extracting: rescuenettrain/train/train-label-img/13059_lab.png
#  extracting: rescuenettrain/train/train-label-img/13064_lab.png
#  extracting: rescuenettrain/train/train-label-img/13065_lab.png
#  extracting: rescuenettrain/train/train-label-img/13098_lab.png
#  extracting: rescuenettrain/train/train-label-img/13115_lab.png
#  extracting: rescuenettrain/train/train-label-img/13117_lab.png
#  extracting: rescuenettrain/train/train-label-img/13129_lab.png
#  extracting: rescuenettrain/train/train-label-img/13176_lab.png
#  extracting: rescuenettrain/train/train-label-img/13177_lab.png
#  extracting: rescuenettrain/train/train-label-img/13084_lab.png
#  extracting: rescuenettrain/train/train-label-img/13156_lab.png
#  extracting: rescuenettrain/train/train-label-img/13157_lab.png
#  extracting: rescuenettrain/train/train-label-img/13201_lab.png
#  extracting: rescuenettrain/train/train-label-img/13223_lab.png
#  extracting: rescuenettrain/train/train-label-img/13240_lab.png
#  extracting: rescuenettrain/train/train-label-img/13243_lab.png
#  extracting: rescuenettrain/train/train-label-img/13221_lab.png
#  extracting: rescuenettrain/train/train-label-img/13260_lab.png
#  extracting: rescuenettrain/train/train-label-img/13263_lab.png
#  extracting: rescuenettrain/train/train-label-img/13280_lab.png
#  extracting: rescuenettrain/train/train-label-img/13282_lab.png
#  extracting: rescuenettrain/train/train-label-img/13312_lab.png
#  extracting: rescuenettrain/train/train-label-img/13332_lab.png
#  extracting: rescuenettrain/train/train-label-img/13313_lab.png
#  extracting: rescuenettrain/train/train-label-img/13351_lab.png
#  extracting: rescuenettrain/train/train-label-img/13352_lab.png
#  extracting: rescuenettrain/train/train-label-img/13372_lab.png
#  extracting: rescuenettrain/train/train-label-img/13393_lab.png
#  extracting: rescuenettrain/train/train-label-img/13410_lab.png
#  extracting: rescuenettrain/train/train-label-img/13413_lab.png
#  extracting: rescuenettrain/train/train-label-img/13451_lab.png
#  extracting: rescuenettrain/train/train-label-img/13453_lab.png
#  extracting: rescuenettrain/train/train-label-img/13470_lab.png
#  extracting: rescuenettrain/train/train-label-img/13471_lab.png
#  extracting: rescuenettrain/train/train-label-img/13491_lab.png
#  extracting: rescuenettrain/train/train-label-img/13502_lab.png
#  extracting: rescuenettrain/train/train-label-img/13522_lab.png
#  extracting: rescuenettrain/train/train-label-img/12995_lab.png
#  extracting: rescuenettrain/train/train-label-img/13044_lab.png
#  extracting: rescuenettrain/train/train-label-img/13137_lab.png
#  extracting: rescuenettrain/train/train-label-img/13430_lab.png
#  extracting: rescuenettrain/train/train-label-img/13431_lab.png
#  extracting: rescuenettrain/train/train-label-img/13501_lab.png
#  extracting: rescuenettrain/train/train-label-img/13503_lab.png
#  extracting: rescuenettrain/train/train-label-img/13523_lab.png
#  extracting: rescuenettrain/train/train-label-img/13561_lab.png
#  extracting: rescuenettrain/train/train-label-img/13562_lab.png
#  extracting: rescuenettrain/train/train-label-img/13628_lab.png
#  extracting: rescuenettrain/train/train-label-img/13634_lab.png
#  extracting: rescuenettrain/train/train-label-img/13078_lab.png
#  extracting: rescuenettrain/train/train-label-img/13109_lab.png
#  extracting: rescuenettrain/train/train-label-img/13371_lab.png
#  extracting: rescuenettrain/train/train-label-img/13373_lab.png
#  extracting: rescuenettrain/train/train-label-img/13490_lab.png
#  extracting: rescuenettrain/train/train-label-img/13669_lab.png
#  extracting: rescuenettrain/train/train-label-img/13675_lab.png
#  extracting: rescuenettrain/train/train-label-img/13677_lab.png
#  extracting: rescuenettrain/train/train-label-img/13719_lab.png
#  extracting: rescuenettrain/train/train-label-img/13725_lab.png
#  extracting: rescuenettrain/train/train-label-img/13739_lab.png
#  extracting: rescuenettrain/train/train-label-img/12949_lab.png
#  extracting: rescuenettrain/train/train-label-img/12996_lab.png
#  extracting: rescuenettrain/train/train-label-img/13635_lab.png
#  extracting: rescuenettrain/train/train-label-img/13689_lab.png
#  extracting: rescuenettrain/train/train-label-img/13694_lab.png
#  extracting: rescuenettrain/train/train-label-img/13695_lab.png
#  extracting: rescuenettrain/train/train-label-img/13726_lab.png
#  extracting: rescuenettrain/train/train-label-img/13745_lab.png
#  extracting: rescuenettrain/train/train-label-img/13746_lab.png
#  extracting: rescuenettrain/train/train-label-img/13747_lab.png
#  extracting: rescuenettrain/train/train-label-img/13786_lab.png
#  extracting: rescuenettrain/train/train-label-img/13787_lab.png
#  extracting: rescuenettrain/train/train-label-img/13798_lab.png
#  extracting: rescuenettrain/train/train-label-img/13047_lab.png
#  extracting: rescuenettrain/train/train-label-img/13067_lab.png
#  extracting: rescuenettrain/train/train-label-img/13079_lab.png
#  extracting: rescuenettrain/train/train-label-img/13099_lab.png
#  extracting: rescuenettrain/train/train-label-img/13637_lab.png
#  extracting: rescuenettrain/train/train-label-img/13779_lab.png
#  extracting: rescuenettrain/train/train-label-img/13870_lab.png
#  extracting: rescuenettrain/train/train-label-img/13871_lab.png
#  extracting: rescuenettrain/train/train-label-img/13890_lab.png
#  extracting: rescuenettrain/train/train-label-img/13891_lab.png
#  extracting: rescuenettrain/train/train-label-img/13892_lab.png
#  extracting: rescuenettrain/train/train-label-img/13921_lab.png
#  extracting: rescuenettrain/train/train-label-img/13922_lab.png
#  extracting: rescuenettrain/train/train-label-img/13923_lab.png
#  extracting: rescuenettrain/train/train-label-img/13962_lab.png
#  extracting: rescuenettrain/train/train-label-img/13963_lab.png
#  extracting: rescuenettrain/train/train-label-img/14002_lab.png
#  extracting: rescuenettrain/train/train-label-img/14003_lab.png
#  extracting: rescuenettrain/train/train-label-img/14021_lab.png
#  extracting: rescuenettrain/train/train-label-img/14022_lab.png
#  extracting: rescuenettrain/train/train-label-img/14023_lab.png
#  extracting: rescuenettrain/train/train-label-img/14042_lab.png
#  extracting: rescuenettrain/train/train-label-img/14082_lab.png
#  extracting: rescuenettrain/train/train-label-img/12928_lab.png
#  extracting: rescuenettrain/train/train-label-img/13018_lab.png
#  extracting: rescuenettrain/train/train-label-img/13696_lab.png
#  extracting: rescuenettrain/train/train-label-img/13980_lab.png
#  extracting: rescuenettrain/train/train-label-img/13983_lab.png
#  extracting: rescuenettrain/train/train-label-img/14150_lab.png
#  extracting: rescuenettrain/train/train-label-img/14151_lab.png
#  extracting: rescuenettrain/train/train-label-img/14153_lab.png
#  extracting: rescuenettrain/train/train-label-img/13901_lab.png
#  extracting: rescuenettrain/train/train-label-img/14080_lab.png
#  extracting: rescuenettrain/train/train-label-img/14191_lab.png
#  extracting: rescuenettrain/train/train-label-img/14192_lab.png
#  extracting: rescuenettrain/train/train-label-img/14205_lab.png
#  extracting: rescuenettrain/train/train-label-img/14206_lab.png
#  extracting: rescuenettrain/train/train-label-img/12994_lab.png
#  extracting: rescuenettrain/train/train-label-img/13025_lab.png
#  extracting: rescuenettrain/train/train-label-img/13810_lab.png
#  extracting: rescuenettrain/train/train-label-img/14219_lab.png
#  extracting: rescuenettrain/train/train-label-img/14226_lab.png
#  extracting: rescuenettrain/train/train-label-img/14227_lab.png
#  extracting: rescuenettrain/train/train-label-img/14239_lab.png
#  extracting: rescuenettrain/train/train-label-img/14259_lab.png
#  extracting: rescuenettrain/train/train-label-img/13657_lab.png
#  extracting: rescuenettrain/train/train-label-img/14265_lab.png
#  extracting: rescuenettrain/train/train-label-img/14266_lab.png
#  extracting: rescuenettrain/train/train-label-img/14286_lab.png
#  extracting: rescuenettrain/train/train-label-img/14287_lab.png
#  extracting: rescuenettrain/train/train-label-img/14298_lab.png
#  extracting: rescuenettrain/train/train-label-img/14328_lab.png
#  extracting: rescuenettrain/train/train-label-img/14329_lab.png
#  extracting: rescuenettrain/train/train-label-img/14334_lab.png
#  extracting: rescuenettrain/train/train-label-img/14335_lab.png
#  extracting: rescuenettrain/train/train-label-img/14354_lab.png
#  extracting: rescuenettrain/train/train-label-img/14355_lab.png
#  extracting: rescuenettrain/train/train-label-img/14357_lab.png
#  extracting: rescuenettrain/train/train-label-img/14348_lab.png
#  extracting: rescuenettrain/train/train-label-img/14349_lab.png
#  extracting: rescuenettrain/train/train-label-img/14369_lab.png
#  extracting: rescuenettrain/train/train-label-img/14374_lab.png
#  extracting: rescuenettrain/train/train-label-img/14377_lab.png
#  extracting: rescuenettrain/train/train-label-img/14429_lab.png
#  extracting: rescuenettrain/train/train-label-img/14519_lab.png
#  extracting: rescuenettrain/train/train-label-img/14539_lab.png
#  extracting: rescuenettrain/train/train-label-img/14584_lab.png
#  extracting: rescuenettrain/train/train-label-img/14585_lab.png
#  extracting: rescuenettrain/train/train-label-img/14586_lab.png
#  extracting: rescuenettrain/train/train-label-img/14692_lab.png
#  extracting: rescuenettrain/train/train-label-img/14693_lab.png
#  extracting: rescuenettrain/train/train-label-img/14701_lab.png
#  extracting: rescuenettrain/train/train-label-img/14703_lab.png
#  extracting: rescuenettrain/train/train-label-img/14527_lab.png
#  extracting: rescuenettrain/train/train-label-img/14544_lab.png
#  extracting: rescuenettrain/train/train-label-img/14545_lab.png
#  extracting: rescuenettrain/train/train-label-img/14700_lab.png
#  extracting: rescuenettrain/train/train-label-img/14720_lab.png
#  extracting: rescuenettrain/train/train-label-img/14721_lab.png
#  extracting: rescuenettrain/train/train-label-img/14740_lab.png
#  extracting: rescuenettrain/train/train-label-img/14741_lab.png
#  extracting: rescuenettrain/train/train-label-img/14743_lab.png
#  extracting: rescuenettrain/train/train-label-img/14760_lab.png
#  extracting: rescuenettrain/train/train-label-img/14780_lab.png
#  extracting: rescuenettrain/train/train-label-img/14781_lab.png
#  extracting: rescuenettrain/train/train-label-img/12929_lab.png
#  extracting: rescuenettrain/train/train-label-img/13019_lab.png
#  extracting: rescuenettrain/train/train-label-img/14368_lab.png
#  extracting: rescuenettrain/train/train-label-img/14815_lab.png
#  extracting: rescuenettrain/train/train-label-img/14817_lab.png
#  extracting: rescuenettrain/train/train-label-img/14836_lab.png
#  extracting: rescuenettrain/train/train-label-img/14837_lab.png
#  extracting: rescuenettrain/train/train-label-img/14190_lab.png
#  extracting: rescuenettrain/train/train-label-img/14835_lab.png
#  extracting: rescuenettrain/train/train-label-img/14875_lab.png
#  extracting: rescuenettrain/train/train-label-img/14888_lab.png
#  extracting: rescuenettrain/train/train-label-img/14894_lab.png
#  extracting: rescuenettrain/train/train-label-img/14897_lab.png
#  extracting: rescuenettrain/train/train-label-img/14918_lab.png
#  extracting: rescuenettrain/train/train-label-img/14924_lab.png
#  extracting: rescuenettrain/train/train-label-img/14927_lab.png
#  extracting: rescuenettrain/train/train-label-img/14938_lab.png
#  extracting: rescuenettrain/train/train-label-img/14944_lab.png
#  extracting: rescuenettrain/train/train-label-img/14964_lab.png
#  extracting: rescuenettrain/train/train-label-img/14965_lab.png
#  extracting: rescuenettrain/train/train-label-img/14967_lab.png
#  extracting: rescuenettrain/train/train-label-img/14998_lab.png
#  extracting: rescuenettrain/train/train-label-img/15008_lab.png
#  extracting: rescuenettrain/train/train-label-img/14904_lab.png
#  extracting: rescuenettrain/train/train-label-img/14905_lab.png
#  extracting: rescuenettrain/train/train-label-img/14907_lab.png
#  extracting: rescuenettrain/train/train-label-img/14925_lab.png
#  extracting: rescuenettrain/train/train-label-img/14958_lab.png
#  extracting: rescuenettrain/train/train-label-img/14959_lab.png
#  extracting: rescuenettrain/train/train-label-img/14999_lab.png
#  extracting: rescuenettrain/train/train-label-img/15009_lab.png
#  extracting: rescuenettrain/train/train-label-img/15029_lab.png
#  extracting: rescuenettrain/train/train-label-img/15048_lab.png
#  extracting: rescuenettrain/train/train-label-img/15049_lab.png
#  extracting: rescuenettrain/train/train-label-img/14856_lab.png
#  extracting: rescuenettrain/train/train-label-img/14869_lab.png
#  extracting: rescuenettrain/train/train-label-img/15015_lab.png
#  extracting: rescuenettrain/train/train-label-img/15017_lab.png
#  extracting: rescuenettrain/train/train-label-img/15028_lab.png
#  extracting: rescuenettrain/train/train-label-img/15055_lab.png
#  extracting: rescuenettrain/train/train-label-img/15057_lab.png
#  extracting: rescuenettrain/train/train-label-img/15094_lab.png
#  extracting: rescuenettrain/train/train-label-img/15126_lab.png
#  extracting: rescuenettrain/train/train-label-img/15127_lab.png
#  extracting: rescuenettrain/train/train-label-img/14857_lab.png
#  extracting: rescuenettrain/train/train-label-img/14896_lab.png
#  extracting: rescuenettrain/train/train-label-img/15014_lab.png
#  extracting: rescuenettrain/train/train-label-img/15035_lab.png
#  extracting: rescuenettrain/train/train-label-img/15075_lab.png
#  extracting: rescuenettrain/train/train-label-img/15139_lab.png
#  extracting: rescuenettrain/train/train-label-img/15145_lab.png
#  extracting: rescuenettrain/train/train-label-img/15146_lab.png
#  extracting: rescuenettrain/train/train-label-img/15147_lab.png
#  extracting: rescuenettrain/train/train-label-img/15159_lab.png
#  extracting: rescuenettrain/train/train-label-img/15211_lab.png
#  extracting: rescuenettrain/train/train-label-img/15273_lab.png
#  extracting: rescuenettrain/train/train-label-img/15290_lab.png
#  extracting: rescuenettrain/train/train-label-img/15291_lab.png
#  extracting: rescuenettrain/train/train-label-img/15303_lab.png
#  extracting: rescuenettrain/train/train-label-img/15105_lab.png
#  extracting: rescuenettrain/train/train-label-img/15186_lab.png
#  extracting: rescuenettrain/train/train-label-img/15341_lab.png
#  extracting: rescuenettrain/train/train-label-img/15342_lab.png
#  extracting: rescuenettrain/train/train-label-img/15343_lab.png
#  extracting: rescuenettrain/train/train-label-img/15361_lab.png
#  extracting: rescuenettrain/train/train-label-img/15362_lab.png
#  extracting: rescuenettrain/train/train-label-img/15363_lab.png
#  extracting: rescuenettrain/train/train-label-img/15380_lab.png
#  extracting: rescuenettrain/train/train-label-img/15382_lab.png
#  extracting: rescuenettrain/train/train-label-img/15400_lab.png
#  extracting: rescuenettrain/train/train-label-img/15403_lab.png
#  extracting: rescuenettrain/train/train-label-img/15420_lab.png
#  extracting: rescuenettrain/train/train-label-img/15421_lab.png
#  extracting: rescuenettrain/train/train-label-img/15440_lab.png
#  extracting: rescuenettrain/train/train-label-img/15443_lab.png
#  extracting: rescuenettrain/train/train-label-img/15532_lab.png
#  extracting: rescuenettrain/train/train-label-img/15533_lab.png
#  extracting: rescuenettrain/train/train-label-img/15572_lab.png
#  extracting: rescuenettrain/train/train-label-img/15592_lab.png
#  extracting: rescuenettrain/train/train-label-img/15625_lab.png
#  extracting: rescuenettrain/train/train-label-img/15638_lab.png
#  extracting: rescuenettrain/train/train-label-img/15644_lab.png
#  extracting: rescuenettrain/train/train-label-img/15645_lab.png
#  extracting: rescuenettrain/train/train-label-img/15658_lab.png
#  extracting: rescuenettrain/train/train-label-img/15659_lab.png
#  extracting: rescuenettrain/train/train-label-img/15664_lab.png
#  extracting: rescuenettrain/train/train-label-img/15665_lab.png
#  extracting: rescuenettrain/train/train-label-img/15698_lab.png
#  extracting: rescuenettrain/train/train-label-img/15463_lab.png
#  extracting: rescuenettrain/train/train-label-img/15552_lab.png
#  extracting: rescuenettrain/train/train-label-img/15618_lab.png
#  extracting: rescuenettrain/train/train-label-img/15627_lab.png
#  extracting: rescuenettrain/train/train-label-img/15709_lab.png
#  extracting: rescuenettrain/train/train-label-img/15717_lab.png
#  extracting: rescuenettrain/train/train-label-img/15756_lab.png
#  extracting: rescuenettrain/train/train-label-img/15769_lab.png
#  extracting: rescuenettrain/train/train-label-img/15776_lab.png
#  extracting: rescuenettrain/train/train-label-img/15777_lab.png
#  extracting: rescuenettrain/train/train-label-img/15441_lab.png
#  extracting: rescuenettrain/train/train-label-img/15553_lab.png
#  extracting: rescuenettrain/train/train-label-img/15678_lab.png
#  extracting: rescuenettrain/train/train-label-img/15685_lab.png
#  extracting: rescuenettrain/train/train-label-img/15686_lab.png
#  extracting: rescuenettrain/train/train-label-img/15729_lab.png
#  extracting: rescuenettrain/train/train-label-img/15801_lab.png
#  extracting: rescuenettrain/train/train-label-img/16071_lab.png
#  extracting: rescuenettrain/train/train-label-img/15571_lab.png
#  extracting: rescuenettrain/train/train-label-img/16053_lab.png
#  extracting: rescuenettrain/train/train-label-img/16072_lab.png
#  extracting: rescuenettrain/train/train-label-img/16324_lab.png
#  extracting: rescuenettrain/train/train-label-img/15480_lab.png
#  extracting: rescuenettrain/train/train-label-img/15551_lab.png
#  extracting: rescuenettrain/train/train-label-img/15735_lab.png
#  extracting: rescuenettrain/train/train-label-img/15736_lab.png
#  extracting: rescuenettrain/train/train-label-img/15737_lab.png
#  extracting: rescuenettrain/train/train-label-img/15803_lab.png
#  extracting: rescuenettrain/train/train-label-img/16012_lab.png
#  extracting: rescuenettrain/train/train-label-img/16031_lab.png
#  extracting: rescuenettrain/train/train-label-img/16032_lab.png
#  extracting: rescuenettrain/train/train-label-img/16033_lab.png
#  extracting: rescuenettrain/train/train-label-img/16297_lab.png
#  extracting: rescuenettrain/train/train-label-img/16304_lab.png
#  extracting: rescuenettrain/train/train-label-img/16307_lab.png
#  extracting: rescuenettrain/train/train-label-img/16325_lab.png
#  extracting: rescuenettrain/train/train-label-img/16498_lab.png
#  extracting: rescuenettrain/train/train-label-img/20422_lab.png
#  extracting: rescuenettrain/train/train-label-img/20423_lab.png
#  extracting: rescuenettrain/train/train-label-img/15077_lab.png
#  extracting: rescuenettrain/train/train-label-img/15460_lab.png
#  extracting: rescuenettrain/train/train-label-img/15800_lab.png
#  extracting: rescuenettrain/train/train-label-img/15860_lab.png
#  extracting: rescuenettrain/train/train-label-img/15861_lab.png
#  extracting: rescuenettrain/train/train-label-img/16093_lab.png
#  extracting: rescuenettrain/train/train-label-img/16229_lab.png
#  extracting: rescuenettrain/train/train-label-img/16296_lab.png
#  extracting: rescuenettrain/train/train-label-img/16305_lab.png
#  extracting: rescuenettrain/train/train-label-img/15106_lab.png
#  extracting: rescuenettrain/train/train-label-img/15166_lab.png
#  extracting: rescuenettrain/train/train-label-img/15167_lab.png
#  extracting: rescuenettrain/train/train-label-img/15823_lab.png
#  extracting: rescuenettrain/train/train-label-img/15840_lab.png
#  extracting: rescuenettrain/train/train-label-img/16090_lab.png
#  extracting: rescuenettrain/train/train-label-img/16092_lab.png
#  extracting: rescuenettrain/train/train-label-img/13024_lab.png
#  extracting: rescuenettrain/train/train-label-img/14308_lab.png
#  extracting: rescuenettrain/train/train-label-img/14375_lab.png
#  extracting: rescuenettrain/train/train-label-img/15882_lab.png
#  extracting: rescuenettrain/train/train-label-img/13583_lab.png
#  extracting: rescuenettrain/train/train-label-img/13707_lab.png
#  extracting: rescuenettrain/train/train-label-img/13765_lab.png
#  extracting: rescuenettrain/train/train-label-img/14063_lab.png
#  extracting: rescuenettrain/train/train-label-img/14171_lab.png
#  extracting: rescuenettrain/train/train-label-img/15165_lab.png
#  extracting: rescuenettrain/train/train-label-img/13582_lab.png
#  extracting: rescuenettrain/train/train-label-img/13648_lab.png
#  extracting: rescuenettrain/train/train-label-img/13649_lab.png
#  extracting: rescuenettrain/train/train-label-img/13766_lab.png
#  extracting: rescuenettrain/train/train-label-img/13767_lab.png
#  extracting: rescuenettrain/train/train-label-img/13811_lab.png
#  extracting: rescuenettrain/train/train-label-img/13813_lab.png
#  extracting: rescuenettrain/train/train-label-img/13903_lab.png
#  extracting: rescuenettrain/train/train-label-img/14246_lab.png
#  extracting: rescuenettrain/train/train-label-img/14247_lab.png
#  extracting: rescuenettrain/train/train-label-img/14315_lab.png
#  extracting: rescuenettrain/train/train-label-img/15796_lab.png
# Archive:  colormask.zip
# warning:  stripped absolute path spec from /
# mapname:  conversion of  failed
#    creating: rescuenetmask/ColorMasks-ValSet/
#    creating: rescuenetmask/ColorMasks-TestSet/
#    creating: rescuenetmask/ColorMasks-TrainSet/
#  extracting: rescuenetmask/ColorMasks-ValSet/10834_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10925_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10966_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10968_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10970_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11070_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11142_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11143_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11144_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11251_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11313_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11336_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11458_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11462_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11511_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11521_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11610_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11618_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11650_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11654_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11655_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11687_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11690_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11696_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11818_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11823_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11826_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11836_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11859_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11876_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11890_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11932_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11936_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12107_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12119_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12134_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12234_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12236_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12238_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12259_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12320_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12479_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12482_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12501_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10892_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11133_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11207_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11259_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11266_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11275_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11288_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11337_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11345_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11346_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11403_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11481_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11482_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11768_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11769_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12069_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12126_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12133_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12148_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12168_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12221_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12298_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12339_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12485_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12538_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12549_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12558_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12571_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12575_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12582_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12592_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12596_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12639_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12645_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12652_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12667_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12673_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12694_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12695_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12722_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12733_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12741_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12746_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12800_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12806_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12810_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12830_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12857_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12887_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12898_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12915_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12917_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12924_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12974_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13040_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13174_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13175_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10869_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10963_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11000_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11122_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11177_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11384_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11391_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11392_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11437_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11491_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11680_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11712_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12077_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12093_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12182_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12224_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12514_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12544_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12608_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12954_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12960_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12961_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12998_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13013_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13180_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13210_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13228_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13251_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13258_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13261_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13262_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13264_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13311_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13321_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13323_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13328_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13329_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13331_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13333_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13338_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13350_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13358_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13388_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13392_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13418_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13423_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13452_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13456_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13464_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13465_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13469_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13513_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13520_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13563_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13564_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13566_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13670_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13674_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13682_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13683_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13737_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14225_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14228_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13868_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13879_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13956_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13992_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13999_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14027_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14031_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14035_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14037_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14043_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14208_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14213_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14238_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14325_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14342_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14344_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14428_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14432_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14587_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14696_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14705_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14750_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14758_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14777_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14802_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14829_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14846_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14873_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14876_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14877_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14900_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14919_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14935_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14945_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14996_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15155_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15174_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15195_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/10954_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11150_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11304_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11359_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/11714_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12045_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12091_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12276_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12440_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12493_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/12559_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13082_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13158_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13211_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13265_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13429_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/13743_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14237_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14269_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14320_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14419_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14596_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14716_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14744_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14768_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14824_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14849_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14863_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14881_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14926_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/14997_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15032_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15056_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15097_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15118_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15142_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15157_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15182_lab.png
#  extracting: rescuenetmask/ColorMasks-ValSet/15214_lab.png
# ...
#  extracting: rescuenetmask/ColorMasks-TrainSet/12035_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12038_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12096_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12153_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12270_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13075_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13446_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13448_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13573_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13576_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13577_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13652_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13912_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13914_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13974_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14073_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14077_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14094_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14099_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14108_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14251_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14281_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15840_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15859_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15882_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16089_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16225_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10799_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11012_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11243_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11564_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11637_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11638_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11667_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11721_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11844_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12011_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12013_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12019_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12026_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12027_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12196_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12254_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12994_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13023_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13024_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13218_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13368_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13369_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13530_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13532_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13533_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13571_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13584_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13644_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13699_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13701_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13705_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13707_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13758_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13873_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13904_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13970_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13979_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14005_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14009_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14018_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14068_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14074_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14075_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14107_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14171_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14189_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14280_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14296_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14308_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14374_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15134_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15162_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15168_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15205_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15835_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15850_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15858_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15870_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15887_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16090_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16091_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16092_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16311_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16312_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10780_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10782_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10839_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10886_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10887_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11009_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11162_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11473_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11663_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11664_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11783_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11925_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12004_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12020_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12022_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12029_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12030_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12199_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12211_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13020_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13030_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13162_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13343_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13531_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13651_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13653_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13700_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13704_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13759_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13937_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13968_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13969_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14006_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14063_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14176_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14200_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14250_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14275_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14375_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14550_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15132_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15849_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16087_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16227_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/20414_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10783_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11224_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11471_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11472_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11474_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11786_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11997_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12002_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12028_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12039_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12040_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12197_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13528_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13582_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13583_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13625_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13643_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13646_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13763_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13764_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13765_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13769_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13811_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13813_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13877_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13878_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13903_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13966_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13967_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14066_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14096_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14172_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14175_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14182_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14203_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14312_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14555_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15163_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15796_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15822_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16085_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16086_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11170_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11171_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11225_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11563_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11662_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11977_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12021_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12041_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12213_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13488_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13527_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13647_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13650_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13756_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13757_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13761_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13766_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13767_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13874_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13913_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13977_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13978_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14015_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14155_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14156_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14157_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14174_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14184_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14185_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14243_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14244_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14249_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14293_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14294_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14556_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15165_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15839_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16075_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16226_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16320_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/10809_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11010_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11168_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11169_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11475_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11561_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11562_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11980_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/11998_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/12212_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13526_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13648_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13649_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13656_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13709_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13710_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13750_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13768_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13875_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13934_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/13935_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14007_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14008_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14016_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14017_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14183_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14201_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14202_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14246_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14247_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14274_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14277_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14278_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/14315_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/15164_lab.png
#  extracting: rescuenetmask/ColorMasks-TrainSet/16496_lab.png

# %%
#core libs
#these are the standard python libraries and cv tools i use for file io and image handling
import os, glob, math, random  #filesystem ops, pattern search, math helpers, rng
import numpy as np             #array math
import cv2                     #opencv for image resizing and padding
from PIL import Image          #reliable png/jpg reading

#torch & utils
#pytorch core plus dataloaders and a progress bar for visibility
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from tqdm.auto import tqdm

#external libs used later
#albumentations handles all of my image/mask augmentations
import albumentations as A
# !pip install segmentation_models_pytorch  #install segmentation models so i can use deeplabv3+ quickly
import segmentation_models_pytorch as smp
from google.colab import drive  #used to persist checkpoints to drive

#pytorch perf/precision knobs
#enable safe loading, allow tf32 paths, and prefer higher matmul precision when available
torch.serialization.add_safe_globals([__import__("numpy")._core.multiarray._reconstruct])  #handle numpy arrays in torch.load safety list
torch.backends.cuda.matmul.allow_tf32 = True  #use tf32 on ampere+ for speed without big accuracy loss
torch.backends.cudnn.allow_tf32 = True        #same idea for cudnn convolutions
try:
    torch.set_float32_matmul_precision("high")  #pytorch 2.x matmul tuning; ok to skip if not supported
except Exception:
    pass

#shared constants used throughout
IGNORE_INDEX = 255  #mask value to ignore when computing loss/metrics
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (0.36.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (0.6.2)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (1.0.21)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (0.23.0+cu126)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.24->segmentation_models_pytorch) (2025.10.5)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 14.2 MB/s eta 0:00:00
# Installing collected packages: segmentation_models_pytorch
# Successfully installed segmentation_models_pytorch-0.5.0

# %%
#fast color(rgb)->class-id lut
#i convert 3-channel color masks into integer class ids using a 256^3 lookup table
def build_color_lut(color_map, ignore_index=IGNORE_INDEX):
    lut = np.full((256,256,256), ignore_index, dtype=np.uint8)  #pre-fill with ignore so unknown colors are skipped
    for (r,g,b), cid in color_map.items():
        lut[r,g,b] = cid
    return lut

def rgbmask_to_ids(mask_rgb: np.ndarray, lut: np.ndarray) -> np.ndarray:
    flat = mask_rgb.reshape(-1,3)                                #flatten to n×3 so we can index the lut
    ids = lut[flat[:,0], flat[:,1], flat[:,2]]                   #vectorized mapping from color to class id
    return ids.reshape(mask_rgb.shape[:2])                       #restore to h×w

class RescueNetSegDataset(Dataset):
    """
    image_dir: JPG/PNG images (e.g., .../train-org-img)
    mask_dir:  color masks named like <stem>_lab.png
    augment:   Albumentations Compose (image+mask) WITHOUT Normalize (recommended)
    normalize: Albumentations A.Normalize(mean,std) OR None
    """
    #this dataset pairs each image with its color mask, applies augs, converts to tensors
    def __init__(self, image_dir, mask_dir, augment=None, normalize=None,
                 color_map=None, return_paths=False):
        assert color_map is not None, "Provide COLOR_MAP"  #i require a color map for lut conversion
        #allow jpg/jpeg/png
        exts = ("*.jpg","*.jpeg","*.png")
        self.image_paths = sorted(sum([glob.glob(os.path.join(image_dir, e)) for e in exts], []))

        #map masks by stem (strip '_lab')
        mask_files = glob.glob(os.path.join(mask_dir, "*.png"))
        mask_dict = {os.path.basename(m).replace("_lab.png",""): m for m in mask_files}

        self.mask_paths = []
        for ip in self.image_paths:
            stem = os.path.splitext(os.path.basename(ip))[0]
            mp = mask_dict.get(stem)
            if mp is None:
                raise RuntimeError(f"No mask found for image: {ip}")  #hard fail so data issues are caught early
            self.mask_paths.append(mp)

        self.augment = augment
        self.normalize = normalize
        self.return_paths = return_paths
        self.lut = build_color_lut(color_map, IGNORE_INDEX)  #precompute lut once per dataset

    def __len__(self): return len(self.image_paths)  #standard dataset length

    def __getitem__(self, idx):
        ip, mp = self.image_paths[idx], self.mask_paths[idx]

        img = np.array(Image.open(ip).convert("RGB"))        #HWC uint8
        msk_rgb = np.array(Image.open(mp).convert("RGB"))    #HWC uint8

        #ensure same size before aug
        if msk_rgb.shape[:2] != img.shape[:2]:
            msk_rgb = cv2.resize(msk_rgb, (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)  #preserve labels

        ids = rgbmask_to_ids(msk_rgb, self.lut)              #HxW uint8/255
        ids = ids.astype(np.int64, copy=False)

        if self.augment is not None:
            out = self.augment(image=img, mask=ids)          #apply joint augs
            img, ids = out["image"], out["mask"]
            ids = ids.astype(np.int64, copy=False)

        #--- normalization guard ---
        if self.normalize is not None:
            #use only this Normalize (float32, mean/std)
            img = self.normalize(image=img)["image"]
        else:
            #if already float32 (e.g., some augs), don't rescale again
            if img.dtype == np.uint8:
                img = img.astype(np.float32) / 255.0
            elif img.dtype != np.float32:
                img = img.astype(np.float32) / 255.0  #fallback

        x = torch.from_numpy(img.transpose(2,0,1))  #C,H,W float32
        y = torch.from_numpy(ids)                   #H,W int64

        if self.return_paths:
            return x, y, (ip, mp)
        return x, y

    def __repr__(self):
        return f"RescueNetSegDataset(n={len(self)}, img0='{os.path.basename(self.image_paths[0])}')"  #quick sanity view

# %%
# !pip install -q albumentations segmentation_models_pytorch  #ensure correct versions are present for colab runtime

#this custom pad transform enforces a minimum canvas size with constant borders for both image and mask
class PadIfNeededConst(A.DualTransform):
    """
    Pad to (min_height, min_width) using CONSTANT border.
    position: 'bottom_right' (default), 'center', or 'top_left'
    - image padding uses `value` (tuple or int)
    - mask padding uses `mask_value` (int), e.g., IGNORE_INDEX
    """
    def __init__(self, min_height, min_width,
                 border_mode=cv2.BORDER_CONSTANT,
                 value=0, mask_value=255, position='bottom_right',
                 always_apply=False, p=1.0):
        super().__init__(always_apply, p)
        self.min_height = int(min_height)
        self.min_width  = int(min_width)
        self.border_mode = border_mode
        self.value = value
        self.mask_value = int(mask_value)
        self.position = position
        if self.border_mode != cv2.BORDER_CONSTANT:
            raise NotImplementedError("PadIfNeededConst currently supports only BORDER_CONSTANT.")  #keep scope simple

    def _pad_amounts(self, h, w):
        dh = max(0, self.min_height - h)
        dw = max(0, self.min_width  - w)
        if dh == 0 and dw == 0:
            return 0, 0, 0, 0
        if self.position == 'center':
            top    = dh // 2
            bottom = dh - top
            left   = dw // 2
            right  = dw - left
        elif self.position == 'top_left':
            top, left = 0, 0
            bottom, right = dh, dw
        else:  # 'bottom_right' (anchor top-left)
            top, left = 0, 0
            bottom, right = dh, dw
        return top, bottom, left, right

    def apply(self, img, **params):
        h, w = img.shape[:2]
        top, bottom, left, right = self._pad_amounts(h, w)
        if top == bottom == left == right == 0:
            return img
        #handle scalar vs 3-tuple image value
        val = self.value
        if img.ndim == 2 and isinstance(val, (tuple, list)):
            val = val[0] if len(val) else 0
        return cv2.copyMakeBorder(img, top, bottom, left, right,
                                  self.border_mode, value=val)

    def apply_to_mask(self, mask, **params):
        h, w = mask.shape[:2]
        top, bottom, left, right = self._pad_amounts(h, w)
        if top == bottom == left == right == 0:
            return mask
        return cv2.copyMakeBorder(mask, top, bottom, left, right,
                                  self.border_mode, value=self.mask_value)

    def get_transform_init_args_names(self):
        return ("min_height", "min_width", "border_mode", "value", "mask_value", "position")

# %%
#==== device & perf flags ====
#select gpu if available and enable cudnn autotune; tf32 flags were set earlier already
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.backends.cudnn.benchmark = True  #let cudnn pick fastest conv algorithms

#amp: prefer bf16 on newer nvidia; else fall back to fp16 with grad scaler
USE_BF16 = True
AMP_DTYPE = torch.bfloat16 if (USE_BF16 and torch.cuda.is_available() and torch.cuda.is_bf16_supported()) else None
SCALER_ENABLED = (device.type == "cuda" and AMP_DTYPE is None)  #scaler is only needed for fp16

#====hyperparams ====
#these are the core knobs for training; i tuned around gpu limits and validation stability
BATCH        = 16
ACCUM_STEPS  = 1
EPOCHS       = 40
LR           = 1e-4
WD           = 1e-4
GRAD_CLIP_N  = 1.0

#colab drive (kept)
#mount google drive so i can save best checkpoints across sessions
drive.mount('/content/drive', force_remount=True)
BASE = "/content/drive/MyDrive/college_data"
os.makedirs(BASE, exist_ok=True)

#==== project globals assumed present elsewhere ====
#color map for mask decoding and essential paths for images/masks
#COLOR_MAP, IGNORE_INDEX, RescueNetSegDataset, PadIfNeededConst, build_color_lut, rgbmask_to_ids
ROOT_MASK = "rescuenetmask"
ROOT_IMG  = "rescuenettrain"

COLOR_MAP = {
    (0, 0, 0): 0,  # background
    (61, 230, 250): 1,  # water
    (180, 120, 120): 2, # building-no-damage
    (235, 255, 7): 3,   # building-medium-damage
    (255, 184, 6): 4,   # building-major-damage
    (255, 0, 0): 5,     # building-total-destruction
    (255, 0, 245): 6,   # vehicle
    (140, 140, 140): 7, # road-clear
    (160, 150, 20): 8,  # road-blocked
    (4, 250, 7): 9,     # tree
    (0, 101, 140): 10,  # pool
}
NUM_CLASSES = max(COLOR_MAP.values()) + 1
LUT = build_color_lut(COLOR_MAP, IGNORE_INDEX)  #prebuild lut once

#==== transforms ====
#pull imagenet preprocessing stats for the chosen encoder
enc = "resnet50"
pp = smp.encoders.get_preprocessing_params(enc, pretrained="imagenet")
mean, std = pp["mean"], pp["std"]

#version-robust ShiftScaleRotate (remove unsupported args like value/mask_value)
#this gives spatial variety while keeping labels valid via constant borders
aug_scale = A.ShiftScaleRotate(
    shift_limit=0.02, scale_limit=0.5, rotate_limit=10,
    border_mode=cv2.BORDER_CONSTANT, p=0.35
)

#version-robust CoarseDropout: prefer new api, fall back to old
#this simulates occlusions/missing pixels and encourages robustness
try:
    coarse = A.CoarseDropout(
        holes_range=(1, 2),
        max_height=48, max_width=48,
        fill_value=0, mask_fill_value=IGNORE_INDEX, p=0.15
    )
except TypeError:
    coarse = A.CoarseDropout(
        min_holes=1, max_holes=2,
        min_height=24, max_height=48,
        min_width=24,  max_width=48,
        fill_value=0, mask_fill_value=IGNORE_INDEX, p=0.15
    )

def _contig(x, **kwargs): return np.ascontiguousarray(x)  #avoid copies later in torch.from_numpy
make_contig = A.Lambda(image=_contig, mask=_contig)

CROP = 768   #if you try 832, reduce batch to fit vram

#final train pipeline: resize→pad→crop with objects→color/motion augs→normalize
train_tfms = A.Compose([
    A.LongestMaxSize(max_size=1024),
    A.HorizontalFlip(p=0.30),
    A.VerticalFlip(p=0.30),
    A.RandomRotate90(p=0.40),
    aug_scale,
    A.SmallestMaxSize(max_size=CROP),
    PadIfNeededConst(min_height=1024, min_width=1024,
                     border_mode=cv2.BORDER_CONSTANT, value=(0,0,0), mask_value=IGNORE_INDEX),
    A.CropNonEmptyMaskIfExists(CROP, CROP, ignore_values=[IGNORE_INDEX], p=1.0),
    A.ColorJitter(brightness=0.12, contrast=0.12, saturation=0.12, hue=0.02, p=0.33),
    A.MotionBlur(blur_limit=(3,7), p=0.10),
    coarse,
    make_contig,
    A.Normalize(mean=mean, std=std, max_pixel_value=255.0),
])

#validation pipeline: center crop with padding and same normalization
val_tfms = A.Compose([
    A.SmallestMaxSize(max_size=CROP),
    PadIfNeededConst(CROP, CROP, value=(0,0,0), mask_value=IGNORE_INDEX, position='center'),
    A.CenterCrop(CROP, CROP),
    make_contig,
    A.Normalize(mean=mean, std=std, max_pixel_value=255.0),
])

print("created transforms")  #quick sanity check
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# created transforms
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /tmp/ipython-input-543049685.py:64: UserWarning: Argument(s) 'holes_range, max_height, max_width, fill_value, mask_fill_value' are not valid for transform CoarseDropout
#   coarse = A.CoarseDropout(

# %%
#==== datasets ====
#build train/val datasets with shared color map and transform pipelines
train_ds_full = RescueNetSegDataset(
    image_dir=f"{ROOT_IMG}/train/train-org-img",
    mask_dir=f"{ROOT_MASK}/ColorMasks-TrainSet",
    color_map=COLOR_MAP,
    augment=train_tfms,
    normalize=None,
)
val_ds_full = RescueNetSegDataset(
    image_dir=f"{ROOT_IMG}/test/test-org-img",
    mask_dir=f"{ROOT_MASK}/ColorMasks-TestSet",
    color_map=COLOR_MAP,
    augment=val_tfms,
    normalize=None,
)
train_ds = train_ds_full
val_ds   = val_ds_full
print("loaded datasets")
print("train size:", len(train_ds))

#==== CE class weights from global pixel counts ====
#compute per-class weights so cross-entropy doesn’t ignore rare classes
def mask_paths_for(subset_or_ds):
    if isinstance(subset_or_ds, Subset):
        base, idxs = subset_or_ds.dataset, subset_or_ds.indices
        return [base.mask_paths[i] for i in idxs]
    return list(subset_or_ds.mask_paths)

train_mask_paths = mask_paths_for(train_ds)

try:
    counts = np.load("train_counts.npy")  #reuse cached counts if present
except:
    counts = np.zeros(NUM_CLASSES, dtype=np.int64)
    for mp in tqdm(train_mask_paths, desc="Counting pixels (full train)"):
        m = np.array(Image.open(mp).convert("RGB"))
        ids = rgbmask_to_ids(m, LUT)
        ids = ids[ids != IGNORE_INDEX]
        if ids.size:
            counts += np.bincount(ids.ravel(), minlength=NUM_CLASSES)
    np.save("train_counts.npy", counts)

w = np.where(counts > 0, 1.0 / np.sqrt(counts.astype(np.float64)), 0.0)  #inverse sqrt freq
nz = w[w > 0]
if nz.size: w /= np.median(nz)  #normalize by median to keep scales reasonable
print("CE weights before clip:", w.tolist())
w = np.clip(w, 0.25, 2.5)  #cap extremes so training remains stable
print("CE weights after clip:", w.tolist())
class_weights = torch.tensor(w, dtype=torch.float32, device=device)  #move to device for loss
# Out:
# loaded datasets
# train size: 3595
# Counting pixels (full train):   0%|          | 0/3595 [00:00<?, ?it/s]
# CE weights before clip: [0.2238355434482673, 0.5688466144668104, 0.997003672957392, 1.0, 1.2510030374282526, 1.3505844513408685, 2.8182346624588757, 0.6164641979141654, 1.2880090871010803, 0.34573726877656497, 6.806674658184886]
# CE weights after clip: [0.25, 0.5688466144668104, 0.997003672957392, 1.0, 1.2510030374282526, 1.3505844513408685, 2.5, 0.6164641979141654, 1.2880090871010803, 0.34573726877656497, 2.5]

# %%
#==== rarity-aware image sampler ====
#this sampler increases chance of picking images that contain rare classes and rare areas
def compute_image_weights(
    dataset, lut, num_classes, ignore_index=IGNORE_INDEX,
    gamma=1.1, lambda_mix=0.9, cap_min=0.25, cap_max=6.0, show_progress=True
):
    img_classes = []
    class_img_freq = np.zeros(num_classes, dtype=np.int64)
    per_img_hist = []
    global_pixel_counts = np.zeros(num_classes, dtype=np.int64)

    it = dataset.mask_paths
    if show_progress: it = tqdm(it, desc="Scanning masks (histograms + presence)")
    for mp in it:
        m = np.array(Image.open(mp).convert("RGB"))
        ids = rgbmask_to_ids(m, lut)
        valid = (ids != ignore_index)
        ids_v = ids[valid]

        hist = np.bincount(ids_v.ravel(), minlength=num_classes).astype(np.int64)
        per_img_hist.append(hist)
        global_pixel_counts += hist

        present = np.flatnonzero(hist > 0)
        img_classes.append(present)
        for c in present: class_img_freq[c] += 1

    #presence term
    class_img_freq = np.maximum(class_img_freq, 1)
    denom_presence = np.sqrt(class_img_freq.astype(np.float64))
    presence_weights = []
    for present in img_classes:
        presence_weights.append(1.0 if len(present)==0 else float(np.sum(1.0 / denom_presence[present])))
    presence_weights = np.asarray(presence_weights, dtype=np.float64)

    #rarity term
    g = global_pixel_counts.astype(np.float64).copy()
    g[g < 1] = 1.0
    rarity = 1.0 / (g ** gamma)
    rarity_weights = []
    for hist in per_img_hist:
        total = float(hist.sum())
        if total <= 0.0:
            rarity_weights.append(1.0)
        else:
            mix = hist.astype(np.float64) / total
            rarity_weights.append(float((rarity * mix).sum()))
    rarity_weights = np.asarray(rarity_weights, dtype=np.float64)

    #blend + clamp + normalize
    w = (1.0 - lambda_mix) * presence_weights + lambda_mix * rarity_weights
    w = np.clip(w, cap_min, cap_max)
    w /= w.sum()
    return torch.as_tensor(w, dtype=torch.double), global_pixel_counts

try:
    img_weights, counts_recalc = torch.load("img_weights_sampler_2.pt", weights_only=False)  #reuse if cached
except:
    img_weights, counts_recalc = compute_image_weights(
        train_ds_full, LUT, NUM_CLASSES,
        ignore_index=IGNORE_INDEX,
        gamma=1.1, lambda_mix=0.9,
        cap_min=0.25, cap_max=6.0, show_progress=True,
    )
    torch.save((img_weights, counts_recalc), "img_weights_sampler_2.pt")

sampler = WeightedRandomSampler(
    weights=img_weights,
    num_samples=len(train_ds_full),
    replacement=True
)

def safe_collate(batch):
    xs, ys = zip(*batch)
    xs = [x.contiguous().clone() for x in xs]  #avoid views interfering with dataloader pins
    ys = [y.contiguous().clone() for y in ys]
    return torch.stack(xs, 0), torch.stack(ys, 0)

train_loader = DataLoader(
    train_ds_full, batch_size=BATCH,
    num_workers=12, persistent_workers=True,
    pin_memory=True, prefetch_factor=4,
    sampler=sampler, collate_fn=safe_collate
)
val_loader = DataLoader(
    val_ds, batch_size=max(1, BATCH), shuffle=False,
    num_workers=12, persistent_workers=True,
    pin_memory=True, prefetch_factor=4, collate_fn=safe_collate
)

print(f"Train batches: {len(train_loader)} | Val batches: {len(val_loader)}")  #sanity check on iteration sizes
# Out:
# Scanning masks (histograms + presence):   0%|          | 0/3595 [00:00<?, ?it/s]
# Train batches: 225 | Val batches: 29

# %%
#==== model + optimizer ====
#build deeplabv3+ with the chosen encoder, optionally warm-start from prior weights
model = smp.DeepLabV3Plus(
    encoder_name=enc,
    encoder_weights="imagenet",
    in_channels=3,
    classes=NUM_CLASSES,
).to(device)

#warm start (optional)
prev_path = "bestprevdeeplabv3+.pth"
if os.path.exists(prev_path):
    try:
        state = torch.load(prev_path, map_location=device)
        model.load_state_dict(state, strict=False)  #strict false so minor head/aux diffs don’t break load
        print(f"Loaded existing weights from {prev_path} (strict=False).")
    except Exception as e:
        print("Warm start skipped:", e)

opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WD)  #adamw has stable weight decay

#==== cosine schedule with 1-epoch warmup (per-step) ====
#i compute per-step lr because grad accumulation changes effective steps per epoch
steps_per_epoch = max(1, len(train_loader) // max(1, ACCUM_STEPS))
total_steps     = EPOCHS * steps_per_epoch
warmup_steps    = steps_per_epoch * 1

def lr_lambda(step):
    if step < warmup_steps:
        return float(step + 1) / float(warmup_steps)  #linear warmup
    progress = (step - warmup_steps) / max(1, (total_steps - warmup_steps))
    return 0.5 * (1.0 + math.cos(math.pi * progress))  #cosine decay

sched = torch.optim.lr_scheduler.LambdaLR(opt, lr_lambda)

#==== losses: CE + Lovasz + per-class focal CE + OHEM (top-k CE) ====
#final hybrid loss that balances overall accuracy, boundaries, hard pixels, and rare classes
ce = torch.nn.CrossEntropyLoss(
    weight=class_weights, ignore_index=IGNORE_INDEX, label_smoothing=0.02
)
lovasz = smp.losses.LovaszLoss(mode="multiclass", per_image=False)

#per-class alpha from CE weights, bump rare class (8) a bit more
alpha_vec = (class_weights / class_weights.sum()).to(device).clone()
alpha_vec[8] *= 1.50   #slightly emphasize road-blocked in my setup
alpha_vec = alpha_vec / alpha_vec.sum()

#per-class gammas: stronger on rare
gamma_map = torch.full((NUM_CLASSES,), 1.5, device=device)
gamma_map[8] = 2.4     #focus even more on specific difficult class

def focal_ce_loss_per_class_gamma(logits, y, alpha, gamma_map, ignore_index=IGNORE_INDEX):
    logp = F.log_softmax(logits, dim=1)
    p    = torch.exp(logp)

    B, C, H, W = logits.shape
    y_flat     = y.view(B, -1)
    logp_flat  = logp.view(B, C, -1)
    p_flat     = p.view(B, C, -1)

    valid = (y_flat != ignore_index)
    idx   = y_flat.clone()
    idx[~valid] = 0

    pt    = torch.gather(p_flat,  1, idx.unsqueeze(1)).squeeze(1)   #prob of the true class per pixel
    logpt = torch.gather(logp_flat,1, idx.unsqueeze(1)).squeeze(1)  #log-prob of the true class per pixel
    alpha_per_pix = alpha[idx]                                       #class weighting by rarity
    gamma_per_pix = gamma_map[idx]                                   #class-specific focusing

    focal = -(alpha_per_pix * (1.0 - pt).pow(gamma_per_pix) * logpt)
    focal = focal * valid
    return focal.sum() / valid.sum().clamp_min(1)

def topk_ce(logits, y, k=0.2):
    """
    Online hard example mining for segmentation.
    k: fraction of valid pixels to keep (e.g., 0.2 = top 20% hardest).
    """
    per_pix = F.cross_entropy(logits, y, weight=class_weights,
                              ignore_index=IGNORE_INDEX, reduction='none')
    valid = (y != IGNORE_INDEX)
    hard = per_pix[valid]
    if hard.numel() == 0:
        return torch.tensor(0.0, device=logits.device)
    k_keep = max(1, int(k * hard.numel()))
    vals, _ = torch.topk(hard, k_keep)
    return vals.mean()

def loss_fn(logits, y):
    ce_term  = ce(logits, y)
    lov_term = lovasz(logits, y)
    foc_term = focal_ce_loss_per_class_gamma(
        logits, y, alpha=alpha_vec, gamma_map=gamma_map, ignore_index=IGNORE_INDEX
    )
    ohem_term = topk_ce(logits, y, k=0.2)  #0.15..0.25 works; i use 0.2 here
    #keep total weight ~1.0; this mix matched my validation behavior best
    return 0.35 * ce_term + 0.30 * lov_term + 0.20 * foc_term + 0.15 * ohem_term

#==== amp scaler: only for fp16, not bf16 ====
scaler = torch.amp.GradScaler(enabled=SCALER_ENABLED)
print("got losses / optimizer / AMP / scheduler")  #checkpoint log
# Out:
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# got losses / optimizer / AMP / scheduler

# %%
#==== ema wrapper (validate & save with ema weights) ====
#ema keeps a smoothed copy of weights that usually validates more stably than raw steps
class EMA:
    def __init__(self, model, decay=0.999):
        self.decay = decay
        self.shadow = {}
        self.backup = {}
        for name, p in model.named_parameters():
            if p.requires_grad:
                self.shadow[name] = p.data.clone()

    @torch.no_grad()
    def update(self, model):
        for name, p in model.named_parameters():
            if p.requires_grad:
                self.shadow[name].mul_(self.decay).add_(p.data, alpha=1.0 - self.decay)

    def apply_shadow(self, model):
        self.backup = {}
        for name, p in model.named_parameters():
            if p.requires_grad:
                self.backup[name] = p.data.clone()
                p.data.copy_(self.shadow[name])

    def restore(self, model):
        for name, p in model.named_parameters():
            if p.requires_grad and name in self.backup:
                p.data.copy_(self.backup[name])
        self.backup = {}

ema = EMA(model, decay=0.999)  #create the ema tracker

#==== metrics ====
#helper to average iou while ignoring background class
def average_miou_ex_background(per_class_ious, bg_id=0):
    arr = np.array(per_class_ious, dtype=np.float64)
    if arr.size <= 1: return float("nan")
    classes = np.delete(arr, bg_id)
    return float(np.nanmean(classes) * 100.0)

@torch.no_grad()
def miou_on_loader_fast(model, loader, n_classes, device,
                        ignore_index=None, use_amp=True, show_progress=True, tta_hflip=True):
    #fast evaluation with optional multi-scale and horizontal flip tta
    def _forward_resized(m, imgs, scale):
        H, W = imgs.shape[-2], imgs.shape[-1]
        if scale != 1.0:
            imgs = F.interpolate(imgs, scale_factor=scale, mode="bilinear", align_corners=False)
        pad_h = (32 - imgs.shape[-2] % 32) % 32
        pad_w = (32 - imgs.shape[-1] % 32) % 32
        imgs_p = F.pad(imgs, (0, pad_w, 0, pad_h)) if (pad_h or pad_w) else imgs
        out = m(imgs_p)
        out = out[..., :imgs.shape[-2], :imgs.shape[-1]]
        return F.interpolate(out, size=(H, W), mode="bilinear", align_corners=False)

    model.eval()
    cm = np.zeros((n_classes, n_classes), dtype=np.int64)  #confusion matrix

    iterator = loader
    pbar = None
    if show_progress:
        try:
            iterator = tqdm(loader, desc="Evaluating", total=len(loader), leave=True)
            pbar = iterator
        except Exception:
            pass

    dev_type = device if isinstance(device, "str") else getattr(device, "type", "cpu")
    autocast_dtype = (torch.bfloat16 if (use_amp and torch.cuda.is_available() and torch.cuda.is_bf16_supported())
                      else (torch.float16 if use_amp else torch.float32))
    scales = [0.85, 1.0, 1.15] if tta_hflip else [1.0]

    try:
        for images, labels in iterator:
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            if use_amp:
                with torch.autocast(device_type=dev_type, dtype=autocast_dtype):
                    logits = 0
                    for s in scales:
                        l = _forward_resized(model, images, s)
                        if tta_hflip:
                            lf = _forward_resized(model, torch.flip(images, dims=[-1]), s)
                            lf = torch.flip(lf, dims=[-1])
                            l = 0.5 * (l + lf)
                        logits = logits + l
                    logits = logits / len(scales)
            else:
                logits = 0
                for s in scales:
                    l = _forward_resized(model, images, s)
                    if tta_hflip:
                        lf = _forward_resized(model, torch.flip(images, dims=[-1]), s)
                        lf = torch.flip(lf, dims=[-1])
                        l = 0.5 * (l + lf)
                    logits = logits + l
                logits = logits / len(scales)

            preds = torch.argmax(logits, dim=1)  #class per pixel

            yt = labels.reshape(-1)
            yp = preds.reshape(-1)

            if ignore_index is not None:
                keep = yt != ignore_index
                yt = yt[keep]; yp = yp[keep]

            keep = (yt >= 0) & (yt < n_classes) & (yp >= 0) & (yp < n_classes)
            yt = yt[keep].to(torch.int64); yp = yp[keep].to(torch.int64)
            if yt.numel() == 0:
                continue

            idx = yt * n_classes + yp
            counts = torch.bincount(idx, minlength=n_classes * n_classes)
            cm += counts.cpu().numpy().reshape(n_classes, n_classes)

            if pbar is not None:
                tp_live = np.diag(cm).astype(np.float64)
                fn_live = cm.sum(axis=1) - np.diag(cm)
                fp_live = cm.sum(axis=0) - np.diag(cm)
                denom_live = tp_live + fn_live + fp_live
                with np.errstate(divide="ignore", invalid="ignore"):
                    ious_live = np.where(denom_live > 0, tp_live / denom_live, np.nan)
                pbar.set_postfix(mIoU=np.nanmean(ious_live))

    finally:
        if pbar is not None:
            pbar.close()

    #==== final metrics from confusion matrix ====
    tp = np.diag(cm).astype(np.float64)
    fn = cm.sum(axis=1) - np.diag(cm)
    fp = cm.sum(axis=0) - np.diag(cm)
    denom_iou = tp + fn + fp

    with np.errstate(divide="ignore", invalid="ignore"):
        ious = np.where(denom_iou > 0, tp / denom_iou, np.nan)

    miou = float(np.nanmean(ious))

    #per-class pixel accuracy: tp/(tp+fn)
    denom_acc = tp + fn
    with np.errstate(divide="ignore", invalid="ignore"):
        per_class_acc = np.where(denom_acc > 0, tp / denom_acc, np.nan)

    #overall pixel accuracy across all valid classes
    total_pixels = cm.sum()
    overall_acc = float(tp.sum() / total_pixels) if total_pixels > 0 else float("nan")

    return ious.tolist(), miou, per_class_acc.tolist(), overall_acc

# %%
#===== training loop =====
#main training: amp + ema + cosine schedule + hybrid loss; saves best ema checkpoint
best_miou, best_path = -1.0, "best_deeplabv3p_ema.pth"
print("beginning the actual loop")
AMP_CAST_DTYPE = AMP_DTYPE or (torch.float16 if device.type == "cuda" else torch.float32)

class EMAHook:
    def __init__(self, model, decay=0.999):
        self.ema = EMA(model, decay)

ema_hook = EMAHook(model, decay=0.999)

global_step = 0
for epoch in range(1, EPOCHS+1):
    pbar = tqdm(train_loader, desc=f"Epoch {epoch:02d} [train]", ncols=100, leave=False)
    model.train()
    running = 0.0
    opt.zero_grad(set_to_none=True)

    for step, (x, y) in enumerate(pbar, 1):
        x = x.to(device, non_blocking=True)
        y = y.to(device, dtype=torch.long, non_blocking=True)

        #amp
        with torch.amp.autocast(device_type=device.type, dtype=AMP_CAST_DTYPE, enabled=(device.type == "cuda")):
            logits = model(x)
            loss = loss_fn(logits, y)

        if SCALER_ENABLED:
            scaler.scale(loss/ACCUM_STEPS).backward()  #scale for fp16 stability
        else:
            (loss/ACCUM_STEPS).backward()

        need_step = (step % ACCUM_STEPS == 0) or (step == len(train_loader))
        if need_step:
            #grad clip
            if SCALER_ENABLED:
                scaler.unscale_(opt)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=GRAD_CLIP_N)

            if SCALER_ENABLED:
                scaler.step(opt); scaler.update()
            else:
                opt.step()
            opt.zero_grad(set_to_none=True)
            ema_hook.ema.update(model)  #update ema shadow after optimizer step
            sched.step()
            global_step += 1

        running += loss.item() * x.size(0)
        pbar.set_postfix(loss=f"{loss.item():.3f}", lr=f"{sched.get_last_lr()[0]:.2e}")  #live feedback

    train_loss = running / len(train_loader.dataset)

    #==== validate with ema weights ====
    ema_hook.ema.apply_shadow(model)
    per_class_ious, val_miou, per_class_acc, overall_acc = miou_on_loader_fast(
        model, val_loader, NUM_CLASSES, device, ignore_index=IGNORE_INDEX, tta_hflip=True
    )
    avg_miou_pct = float(np.nanmean(np.array(per_class_ious[1:], dtype=np.float64)) * 100.0)  #exclude background
    ema_hook.ema.restore(model)

    #nice prints
    print("Per-class IoUs:", per_class_ious)
    print("Per-class Accuracies:", [None if np.isnan(a) else float(a) for a in per_class_acc])
    print(f"Overall Pixel Acc: {overall_acc*100:.2f}%")
    print(f"Avg mIoU (no background): {avg_miou_pct:.2f}%")
    print(f"Epoch {epoch:02d} | train_loss {train_loss:.4f} | val_mIoU (EMA+TTA) {val_miou:.3f}")

    if val_miou > best_miou:
        best_miou = val_miou
        #save ema weights as best
        ema_hook.ema.apply_shadow(model)
        torch.save(model.state_dict(), best_path)
        ema_hook.ema.restore(model)
        print(f"  ↳ saved best EMA weights to {best_path}")
        version = 13
        torch.save(model.state_dict(), f"{BASE}/v{version}_deeplabv3p_ema_e{epoch}miou{val_miou:.3f}.pth")
        print("saved to drive")

#gpu vram info
if torch.cuda.is_available():
    free, total = torch.cuda.mem_get_info()
    print(f"GPU VRAM used: {(total-free)/1e9:.2f} GB / {total/1e9:.2f} GB  ({torch.cuda.get_device_name(0)})")

print(f"Done. Best EMA+TTA val mIoU: {best_miou:.3f}")  #final summary so i can compare runs
# Out:
# beginning the actual loop
# Epoch 01 [train]:   0%|                                                     | 0/225 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3589463043.py in <cell line: 0>()
#      18     opt.zero_grad(set_to_none=True)
#      19
# ---> 20     for step, (x, y) in enumerate(pbar, 1):
#      21         x = x.to(device, non_blocking=True)
#      22         y = y.to(device, dtype=torch.long, non_blocking=True)
#
# /usr/local/lib/python3.12/dist-packages/tqdm/notebook.py in __iter__(self)
#     248         try:
#     249             it = super().__iter__()
# --> 250             for obj in it:
#     251                 # return super(tqdm...) will not catch exception
#     252                 yield obj
#
# /usr/local/lib/python3.12/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     732                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     733                 self._reset()  # type: ignore[call-arg]
# --> 734             data = self._next_data()
#     735             self._num_yielded += 1
#     736             if (
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1490
#    1491             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1492             idx, data = self._get_data()
#    1493             self._tasks_outstanding -= 1
#    1494             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1442         elif self._pin_memory:
#    1443             while self._pin_memory_thread.is_alive():
# -> 1444                 success, data = self._try_get_data()
#    1445                 if success:
#    1446                     return data
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1283         #   (bool: whether successfully get data, any: data if successful else None)
#    1284         try:
# -> 1285             data = self._data_queue.get(timeout=timeout)
#    1286             return (True, data)
#    1287         except Exception as e:
#
# /usr/lib/python3.12/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.12/threading.py in wait(self, timeout)
#     357             else:
#     358                 if timeout > 0:
# --> 359                     gotit = waiter.acquire(True, timeout)
#     360                 else:
#     361                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
